# %% [markdown]
# # WebCam Detection & Prediction using YOLO
#
# **Note:**
# 1. This script is for Pre-defined Classes Prediction - Not for *Custom Data*
# 2. So take predefined Models - which has predefined weights for our prediction, but it will predict the same items.

# %%
#!pip install ultralytics

# %%
import cv2
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

video = cv2.VideoCapture(0)

while True:
    success, frame = video.read()
    if success == True:
        results = model(frame)
        print(results)
        
        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                confidence = float(box.conf[0])
                class_id = int(box.cls[0])
                class_name = model.names[class_id]
                cv2.rectangle(frame,(x1, y1),(x2, y2),(0, 255, 0),3)
                label = f"{class_name} {confidence:.2f}"
                cv2.putText(frame,label,(x1, y1 - 10),cv2.FONT_HERSHEY_SIMPLEX,0.7,(0, 255, 0),2) # Put Label Above Box

        cv2.imshow("YOLO Webcam Detection", frame)
        key = cv2.waitKey(delay = 1)
        if key == 113 or key == 81:
            break
   
    else:
        print("Video Stopped")

video.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1 chair, 256.7ms
# Speed: 4.8ms preprocess, 256.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [194, 184, 189],
#         [195, 185, 191],
#         [191, 181, 187]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [193, 184, 188],
#         [195, 185, 190],
#         [191, 181, 187]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [189, 180, 183],
#         [191, 182, 185],
#         [188, 179, 183]],
#
#        ...,
#
#        [[140, 133, 130],
#         [148, 141, 138],
#         [144, 137, 134],
#         ...,
#         [130, 120,  99],
#         [129, 119,  99],
#         [130, 120, 100]],
#
#        [[153, 147, 142],
#         [151, 145, 140],
#         [138, 132, 127],
#         ...,
#         [137, 127, 103],
#         [133, 123, 100],
#         [129, 118,  97]],
#
#        [[148, 142, 137],
#         [145, 139, 134],
#         [144, 138, 133],
#         ...,
#         [130, 120,  96],
#         [130, 120,  97],
#         [134, 124, 101]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 4.834799998207018, 'inference': 256.7055999970762, 'postprocess': 2.6273999974364415}]
#
# 0: 480x640 1 person, 1 cup, 1 chair, 96.5ms
# Speed: 3.7ms preprocess, 96.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [193, 186, 194],
#         [186, 179, 187],
#         [186, 179, 186]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [191, 184, 191],
#         [192, 185, 192],
#         [191, 184, 191]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [185, 181, 187],
#         [186, 181, 186],
#         [181, 175, 180]],
#
#        ...,
#
#        [[140, 135, 134],
#         [142, 137, 136],
#         [139, 133, 132],
#         ...,
#         [130, 118, 104],
#         [130, 118, 104],
#         [128, 116, 101]],
#
#        [[139, 133, 134],
#         [144, 138, 139],
#         [140, 133, 134],
#         ...,
#         [140, 128, 111],
#         [141, 128, 112],
#         [143, 130, 115]],
#
#        [[140, 134, 135],
#         [148, 142, 143],
#         [139, 132, 133],
#         ...,
#         [125, 113,  95],
#         [127, 115,  98],
#         [139, 126, 110]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 3.7148999981582165, 'inference': 96.50410000176635, 'postprocess': 1.5659000055165961}]
#
# 0: 480x640 1 person, 1 chair, 97.8ms
# Speed: 3.5ms preprocess, 97.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [187, 178, 184],
#         [183, 174, 178],
#         [188, 178, 182]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [189, 181, 185],
#         [183, 174, 177],
#         [184, 175, 177]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [180, 173, 174],
#         [176, 169, 169],
#         [176, 170, 169]],
#
#        ...,
#
#        [[135, 129, 128],
#         [134, 128, 127],
#         [135, 129, 128],
#         ...,
#         [125, 117, 100],
#         [129, 123, 104],
#         [124, 119, 100]],
#
#        [[139, 131, 131],
#         [140, 133, 131],
#         [140, 134, 132],
#         ...,
#         [126, 120, 101],
#         [133, 128, 109],
#         [126, 122, 103]],
#
#        [[144, 135, 135],
#         [143, 136, 134],
#         [143, 137, 134],
#         ...,
#         [127, 122, 103],
#         [133, 129, 110],
#         [126, 124, 104]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 3.5160999977961183, 'inference': 97.75729999819305, 'postprocess': 1.1461000103736296}]
#
# 0: 480x640 1 person, 1 chair, 2 cell phones, 77.7ms
# Speed: 2.7ms preprocess, 77.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [191, 179, 184],
#         [189, 178, 182],
#         [186, 175, 178]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [186, 175, 178],
#         [184, 172, 177],
#         [185, 173, 178]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [184, 172, 175],
#         [184, 172, 175],
#         [188, 176, 181]],
#
#        ...,
#
#        [[137, 137, 135],
#         [136, 135, 134],
#         [138, 137, 136],
#         ...,
#         [131, 122, 102],
#         [125, 116,  96],
#         [121, 112,  92]],
#
#        [[137, 138, 135],
#         [132, 133, 130],
#         [133, 132, 131],
#         ...,
#         [135, 126, 106],
#         [141, 132, 112],
#         [139, 130, 110]],
#
#        [[134, 137, 132],
#         [134, 135, 131],
#         [134, 134, 131],
#         ...,
#         [128, 119,  99],
#         [139, 130, 110],
#         [136, 127, 107]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.71499999507796, 'inference': 77.74989999597892, 'postprocess': 1.0603000118862838}]
#
# 0: 480x640 1 person, 1 chair, 1 cell phone, 78.7ms
# Speed: 2.3ms preprocess, 78.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [186, 182, 185],
#         [183, 180, 182],
#         [177, 175, 177]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [179, 173, 177],
#         [180, 176, 179],
#         [177, 174, 177]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [181, 175, 179],
#         [182, 177, 181],
#         [178, 173, 178]],
#
#        ...,
#
#        [[141, 136, 133],
#         [147, 142, 139],
#         [147, 142, 139],
#         ...,
#         [126, 109,  92],
#         [126, 108,  91],
#         [132, 114,  97]],
#
#        [[135, 130, 127],
#         [140, 135, 132],
#         [140, 135, 132],
#         ...,
#         [137, 121, 104],
#         [135, 119, 102],
#         [128, 113,  95]],
#
#        [[138, 133, 130],
#         [140, 135, 132],
#         [140, 135, 132],
#         ...,
#         [134, 120, 102],
#         [133, 119, 101],
#         [129, 116,  98]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.264800001285039, 'inference': 78.71470000827685, 'postprocess': 1.223500003106892}]
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 81.2ms
# Speed: 2.6ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [180, 174, 175],
#         [175, 169, 170],
#         [179, 173, 174]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [180, 174, 175],
#         [176, 170, 171],
#         [183, 177, 178]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [185, 179, 180],
#         [182, 176, 177],
#         [189, 183, 184]],
#
#        ...,
#
#        [[136, 133, 129],
#         [138, 135, 131],
#         [137, 134, 130],
#         ...,
#         [121, 109,  83],
#         [122, 109,  83],
#         [126, 112,  87]],
#
#        [[137, 133, 128],
#         [142, 138, 133],
#         [136, 132, 127],
#         ...,
#         [123, 112,  89],
#         [124, 111,  89],
#         [127, 113,  90]],
#
#        [[140, 135, 130],
#         [144, 139, 134],
#         [135, 130, 125],
#         ...,
#         [124, 113,  92],
#         [125, 113,  92],
#         [127, 114,  93]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.6092000043718144, 'inference': 81.19979999901261, 'postprocess': 1.0099000064656138}]
#
# 0: 480x640 1 person, 1 chair, 83.1ms
# Speed: 2.5ms preprocess, 83.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [184, 169, 169],
#         [182, 167, 167],
#         [186, 171, 171]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [183, 168, 169],
#         [178, 164, 165],
#         [180, 166, 167]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [176, 162, 164],
#         [172, 158, 160],
#         [174, 160, 162]],
#
#        ...,
#
#        [[128, 126, 126],
#         [135, 133, 133],
#         [131, 129, 128],
#         ...,
#         [124, 107,  90],
#         [114,  97,  81],
#         [117, 100,  84]],
#
#        [[132, 129, 128],
#         [138, 135, 134],
#         [135, 132, 131],
#         ...,
#         [131, 115,  95],
#         [137, 121, 102],
#         [136, 120, 101]],
#
#        [[132, 128, 126],
#         [136, 132, 131],
#         [133, 129, 128],
#         ...,
#         [135, 120,  98],
#         [138, 122, 102],
#         [137, 121, 101]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.47500000114087, 'inference': 83.13009999983478, 'postprocess': 1.1094999936176464}]
#
# 0: 480x640 1 person, 1 chair, 72.9ms
# Speed: 2.1ms preprocess, 72.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [176, 168, 174],
#         [178, 171, 176],
#         [180, 173, 178]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [181, 173, 178],
#         [180, 171, 177],
#         [178, 169, 175]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [180, 171, 175],
#         [181, 171, 177],
#         [174, 164, 170]],
#
#        ...,
#
#        [[129, 131, 125],
#         [131, 133, 127],
#         [134, 136, 130],
#         ...,
#         [124, 114,  93],
#         [127, 117,  97],
#         [116, 106,  86]],
#
#        [[131, 133, 128],
#         [132, 134, 129],
#         [132, 134, 128],
#         ...,
#         [126, 116,  92],
#         [125, 115,  92],
#         [115, 105,  82]],
#
#        [[127, 128, 125],
#         [129, 131, 126],
#         [129, 131, 125],
#         ...,
#         [125, 115,  90],
#         [125, 115,  90],
#         [122, 112,  87]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.1444000012706965, 'inference': 72.91230000555515, 'postprocess': 1.1442000104580075}]
#
# 0: 480x640 1 person, 1 chair, 1 cell phone, 77.5ms
# Speed: 2.4ms preprocess, 77.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [175, 177, 178],
#         [172, 174, 176],
#         [173, 175, 177]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [170, 171, 172],
#         [173, 174, 175],
#         [176, 177, 178]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [176, 175, 175],
#         [176, 175, 175],
#         [166, 165, 165]],
#
#        ...,
#
#        [[133, 130, 126],
#         [143, 139, 136],
#         [141, 138, 134],
#         ...,
#         [118, 108,  85],
#         [117, 107,  84],
#         [111, 101,  78]],
#
#        [[137, 131, 128],
#         [140, 133, 130],
#         [144, 138, 134],
#         ...,
#         [127, 117,  94],
#         [129, 119,  96],
#         [122, 112,  89]],
#
#        [[148, 140, 137],
#         [134, 126, 123],
#         [136, 129, 124],
#         ...,
#         [134, 124, 101],
#         [130, 120,  97],
#         [120, 110,  87]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.4258000048575923, 'inference': 77.49899999180343, 'postprocess': 1.1520000116433948}]
#
# 0: 480x640 1 person, 1 chair, 1 cell phone, 74.5ms
# Speed: 2.5ms preprocess, 74.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [170, 168, 164],
#         [170, 169, 163],
#         [172, 171, 164]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [176, 173, 169],
#         [172, 169, 164],
#         [170, 167, 162]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [178, 173, 170],
#         [178, 174, 170],
#         [175, 171, 167]],
#
#        ...,
#
#        [[128, 127, 121],
#         [132, 131, 125],
#         [134, 133, 127],
#         ...,
#         [119, 111,  87],
#         [116, 108,  84],
#         [116, 108,  84]],
#
#        [[134, 134, 127],
#         [133, 133, 126],
#         [134, 134, 128],
#         ...,
#         [120, 113,  87],
#         [120, 113,  87],
#         [124, 117,  90]],
#
#        [[130, 131, 122],
#         [128, 130, 122],
#         [130, 131, 124],
#         ...,
#         [120, 113,  87],
#         [123, 116,  89],
#         [123, 117,  89]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.465099998516962, 'inference': 74.45820000430103, 'postprocess': 2.3169000050984323}]
#
# 0: 480x640 1 person, 1 chair, 95.5ms
# Speed: 2.5ms preprocess, 95.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [180, 176, 174],
#         [176, 172, 170],
#         [170, 166, 165]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [180, 176, 174],
#         [174, 170, 168],
#         [166, 162, 161]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [180, 176, 174],
#         [178, 174, 173],
#         [174, 170, 169]],
#
#        ...,
#
#        [[133, 129, 125],
#         [134, 130, 126],
#         [131, 127, 123],
#         ...,
#         [127, 115,  98],
#         [124, 110,  94],
#         [129, 114,  98]],
#
#        [[133, 130, 125],
#         [133, 130, 125],
#         [134, 131, 126],
#         ...,
#         [130, 118,  99],
#         [130, 118, 100],
#         [135, 123, 105]],
#
#        [[132, 131, 125],
#         [133, 132, 126],
#         [136, 135, 129],
#         ...,
#         [126, 115,  95],
#         [127, 115,  96],
#         [132, 120, 102]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.460400006384589, 'inference': 95.54270000080578, 'postprocess': 3.4078000026056543}]
#
# 0: 480x640 1 person, 1 chair, 122.1ms
# Speed: 3.5ms preprocess, 122.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [166, 172, 177],
#         [169, 174, 178],
#         [172, 177, 180]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [166, 173, 176],
#         [172, 177, 180],
#         [172, 177, 179]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [168, 174, 176],
#         [174, 178, 179],
#         [171, 176, 175]],
#
#        ...,
#
#        [[132, 128, 123],
#         [140, 136, 131],
#         [144, 139, 136],
#         ...,
#         [113, 105,  81],
#         [118, 110,  86],
#         [123, 115,  91]],
#
#        [[135, 128, 125],
#         [137, 131, 128],
#         [140, 134, 132],
#         ...,
#         [115, 108,  82],
#         [118, 111,  85],
#         [120, 113,  87]],
#
#        [[135, 127, 124],
#         [134, 127, 125],
#         [134, 128, 126],
#         ...,
#         [123, 116,  89],
#         [120, 113,  86],
#         [120, 113,  86]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 3.5131000040564686, 'inference': 122.05999999423511, 'postprocess': 1.5875999961281195}]
#
# 0: 480x640 1 person, 1 chair, 127.5ms
# Speed: 2.4ms preprocess, 127.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [186, 180, 178],
#         [175, 170, 168],
#         [177, 172, 171]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [175, 169, 168],
#         [174, 168, 167],
#         [175, 170, 168]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [181, 174, 175],
#         [184, 178, 177],
#         [174, 168, 166]],
#
#        ...,
#
#        [[137, 134, 129],
#         [139, 136, 131],
#         [134, 131, 126],
#         ...,
#         [125, 116,  95],
#         [129, 121,  99],
#         [122, 114,  92]],
#
#        [[135, 132, 128],
#         [133, 130, 126],
#         [133, 130, 125],
#         ...,
#         [123, 117,  92],
#         [131, 123,  99],
#         [127, 119,  95]],
#
#        [[139, 136, 133],
#         [134, 131, 127],
#         [138, 135, 130],
#         ...,
#         [125, 119,  93],
#         [129, 122,  96],
#         [127, 119,  93]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.44609999936074, 'inference': 127.54870000935625, 'postprocess': 1.4621000009356067}]
#
# 0: 480x640 1 person, 1 chair, 1 cell phone, 111.7ms
# Speed: 3.8ms preprocess, 111.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [183, 181, 181],
#         [171, 167, 166],
#         [175, 171, 169]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [182, 180, 180],
#         [171, 168, 167],
#         [175, 172, 170]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [176, 174, 173],
#         [167, 165, 164],
#         [169, 167, 166]],
#
#        ...,
#
#        [[141, 137, 135],
#         [137, 133, 131],
#         [137, 132, 130],
#         ...,
#         [124, 105,  90],
#         [131, 111,  97],
#         [130, 110,  96]],
#
#        [[144, 139, 136],
#         [141, 136, 133],
#         [138, 133, 130],
#         ...,
#         [126, 108,  94],
#         [133, 114, 100],
#         [132, 112,  97]],
#
#        [[138, 132, 129],
#         [136, 130, 127],
#         [137, 131, 128],
#         ...,
#         [129, 111,  97],
#         [135, 116, 101],
#         [135, 115, 100]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 3.7611000007018447, 'inference': 111.6935000027297, 'postprocess': 1.3467999960994348}]
#
# 0: 480x640 1 person, 1 chair, 107.6ms
# Speed: 2.6ms preprocess, 107.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [182, 178, 180],
#         [183, 180, 183],
#         [173, 171, 174]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [182, 178, 179],
#         [183, 180, 182],
#         [178, 175, 177]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [175, 173, 172],
#         [177, 175, 175],
#         [177, 174, 176]],
#
#        ...,
#
#        [[130, 129, 126],
#         [128, 127, 123],
#         [133, 133, 127],
#         ...,
#         [127, 115,  98],
#         [127, 115,  97],
#         [135, 123, 105]],
#
#        [[133, 132, 128],
#         [131, 130, 126],
#         [132, 131, 127],
#         ...,
#         [131, 118, 102],
#         [132, 118, 102],
#         [134, 119, 103]],
#
#        [[135, 134, 130],
#         [130, 129, 125],
#         [126, 125, 121],
#         ...,
#         [123, 110,  95],
#         [127, 112,  97],
#         [132, 117, 102]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.5593999889679253, 'inference': 107.63020000013057, 'postprocess': 1.4507000014418736}]
#
# 0: 480x640 1 person, 1 chair, 1 cell phone, 108.3ms
# Speed: 2.8ms preprocess, 108.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [174, 174, 173],
#         [179, 180, 177],
#         [182, 184, 179]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [176, 177, 175],
#         [180, 181, 177],
#         [180, 182, 177]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [179, 180, 177],
#         [179, 181, 176],
#         [172, 174, 169]],
#
#        ...,
#
#        [[138, 132, 131],
#         [141, 135, 133],
#         [141, 135, 133],
#         ...,
#         [129, 119,  96],
#         [126, 116,  93],
#         [127, 117,  94]],
#
#        [[136, 131, 129],
#         [141, 135, 133],
#         [143, 137, 134],
#         ...,
#         [125, 115,  92],
#         [122, 110,  88],
#         [127, 114,  92]],
#
#        [[133, 129, 125],
#         [138, 134, 130],
#         [143, 138, 134],
#         ...,
#         [122, 111,  89],
#         [125, 112,  90],
#         [129, 116,  94]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.7743999962694943, 'inference': 108.34679999970831, 'postprocess': 1.516300006187521}]
#
# 0: 480x640 1 person, 1 chair, 112.6ms
# Speed: 2.1ms preprocess, 112.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [181, 172, 171],
#         [180, 172, 171],
#         [182, 174, 173]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [187, 179, 179],
#         [182, 174, 174],
#         [179, 171, 171]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [187, 180, 181],
#         [182, 175, 176],
#         [179, 172, 173]],
#
#        ...,
#
#        [[139, 138, 131],
#         [137, 136, 129],
#         [139, 138, 131],
#         ...,
#         [134, 123, 100],
#         [129, 119,  96],
#         [130, 120,  97]],
#
#        [[139, 139, 133],
#         [138, 138, 132],
#         [138, 137, 131],
#         ...,
#         [133, 123,  99],
#         [128, 119,  95],
#         [130, 121,  97]],
#
#        [[142, 143, 137],
#         [144, 144, 138],
#         [143, 141, 136],
#         ...,
#         [135, 126, 102],
#         [131, 124,  99],
#         [135, 128, 103]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.0822000078624114, 'inference': 112.61309999099467, 'postprocess': 1.433299999916926}]
#
# 0: 480x640 1 person, 1 chair, 104.5ms
# Speed: 3.8ms preprocess, 104.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# ...
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [192, 192, 196],
#         [187, 186, 190],
#         [185, 184, 188]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [194, 193, 197],
#         [191, 190, 194],
#         [189, 188, 192]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [196, 194, 197],
#         [197, 195, 198],
#         [191, 189, 192]],
#
#        ...,
#
#        [[147, 140, 137],
#         [149, 142, 139],
#         [152, 145, 142],
#         ...,
#         [126, 118,  99],
#         [128, 120, 101],
#         [125, 117,  98]],
#
#        [[146, 139, 136],
#         [139, 132, 129],
#         [141, 134, 131],
#         ...,
#         [136, 125, 107],
#         [138, 127, 109],
#         [132, 121, 103]],
#
#        [[151, 144, 141],
#         [145, 138, 135],
#         [148, 141, 138],
#         ...,
#         [145, 132, 114],
#         [141, 128, 110],
#         [130, 117,  99]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.493699998012744, 'inference': 69.50539999525063, 'postprocess': 1.5589000104228035}]
#
# 0: 480x640 1 person, 1 cell phone, 69.6ms
# Speed: 5.4ms preprocess, 69.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [195, 189, 193],
#         [194, 188, 192],
#         [197, 192, 195]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [189, 184, 186],
#         [188, 183, 185],
#         [193, 188, 190]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [193, 188, 189],
#         [185, 180, 181],
#         [183, 178, 179]],
#
#        ...,
#
#        [[147, 144, 139],
#         [148, 145, 140],
#         [137, 133, 128],
#         ...,
#         [135, 128, 109],
#         [132, 126, 107],
#         [124, 118,  99]],
#
#        [[148, 144, 139],
#         [149, 145, 140],
#         [146, 142, 137],
#         ...,
#         [131, 123, 103],
#         [135, 128, 108],
#         [137, 130, 110]],
#
#        [[142, 137, 132],
#         [145, 140, 135],
#         [148, 144, 139],
#         ...,
#         [131, 122, 101],
#         [137, 130, 108],
#         [139, 133, 111]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 5.396000007749535, 'inference': 69.5525000046473, 'postprocess': 1.1272999981883913}]
#
# 0: 480x640 1 person, 1 cell phone, 75.4ms
# Speed: 2.4ms preprocess, 75.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [193, 193, 193],
#         [190, 190, 190],
#         [190, 190, 190]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [191, 191, 191],
#         [189, 189, 189],
#         [185, 185, 185]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [187, 187, 187],
#         [191, 191, 191],
#         [188, 188, 188]],
#
#        ...,
#
#        [[149, 144, 145],
#         [144, 139, 140],
#         [141, 136, 137],
#         ...,
#         [128, 116,  94],
#         [131, 119,  97],
#         [133, 121,  99]],
#
#        [[151, 146, 145],
#         [144, 139, 138],
#         [144, 139, 138],
#         ...,
#         [141, 128, 107],
#         [142, 129, 107],
#         [147, 134, 112]],
#
#        [[152, 146, 144],
#         [146, 140, 138],
#         [148, 142, 140],
#         ...,
#         [142, 128, 108],
#         [138, 125, 104],
#         [144, 131, 109]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.4025000020628795, 'inference': 75.42870000179391, 'postprocess': 1.6220000106841326}]
#
# 0: 480x640 1 person, 72.1ms
# Speed: 2.8ms preprocess, 72.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [191, 192, 203],
#         [187, 187, 201],
#         [183, 182, 198]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [192, 193, 203],
#         [193, 193, 206],
#         [189, 189, 203]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [189, 191, 199],
#         [193, 194, 204],
#         [190, 191, 201]],
#
#        ...,
#
#        [[148, 142, 137],
#         [152, 146, 141],
#         [151, 146, 141],
#         ...,
#         [134, 122, 104],
#         [135, 123, 105],
#         [133, 121, 103]],
#
#        [[146, 141, 136],
#         [151, 146, 141],
#         [152, 148, 143],
#         ...,
#         [142, 129, 110],
#         [145, 134, 114],
#         [137, 126, 106]],
#
#        [[147, 143, 138],
#         [152, 148, 143],
#         [156, 152, 147],
#         ...,
#         [142, 129, 108],
#         [146, 135, 114],
#         [140, 129, 108]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.8406999917933717, 'inference': 72.05259999318514, 'postprocess': 1.1508000025060028}]
#
# 0: 480x640 1 person, 2 cell phones, 93.3ms
# Speed: 2.4ms preprocess, 93.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [196, 185, 188],
#         [198, 184, 188],
#         [196, 181, 185]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [200, 189, 192],
#         [196, 183, 187],
#         [191, 178, 183]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [196, 186, 190],
#         [195, 185, 189],
#         [194, 184, 188]],
#
#        ...,
#
#        [[146, 139, 136],
#         [144, 137, 134],
#         [144, 137, 134],
#         ...,
#         [137, 129, 107],
#         [134, 126, 106],
#         [136, 129, 109]],
#
#        [[147, 141, 136],
#         [148, 142, 137],
#         [144, 139, 134],
#         ...,
#         [134, 126, 103],
#         [139, 132, 110],
#         [140, 133, 113]],
#
#        [[148, 142, 137],
#         [151, 145, 140],
#         [147, 142, 137],
#         ...,
#         [136, 128, 105],
#         [141, 134, 112],
#         [134, 127, 107]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.3757000017212704, 'inference': 93.3348999969894, 'postprocess': 1.0883000068133697}]
#
# 0: 480x640 1 person, 1 cell phone, 83.3ms
# Speed: 2.6ms preprocess, 83.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [189, 187, 187],
#         [188, 184, 185],
#         [193, 188, 189]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241],
#         ...,
#         [189, 187, 187],
#         [190, 186, 187],
#         [191, 186, 187]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [242, 242, 242],
#         ...,
#         [190, 185, 186],
#         [194, 189, 190],
#         [192, 187, 188]],
#
#        ...,
#
#        [[151, 147, 143],
#         [149, 145, 141],
#         [148, 143, 140],
#         ...,
#         [129, 122, 102],
#         [131, 124, 104],
#         [132, 124, 105]],
#
#        [[146, 143, 138],
#         [148, 145, 140],
#         [150, 146, 141],
#         ...,
#         [131, 123, 103],
#         [131, 123, 103],
#         [129, 122, 102]],
#
#        [[143, 142, 136],
#         [151, 148, 143],
#         [146, 142, 137],
#         ...,
#         [132, 123, 103],
#         [128, 120, 100],
#         [124, 118,  96]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'D:\\ProITBridge\\Courses\\DL_Course\\12_YOLO_CrashCourse\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.5981999933719635, 'inference': 83.31700001144782, 'postprocess': 1.3941000070190057}]
#
# 0: 480x640 1 person, 1 cell phone, 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# # THE END!
